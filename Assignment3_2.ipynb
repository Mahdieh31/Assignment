# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\noora\OneDrive\Desktop\MahdiehCV\test\Assignment3\Table1.csv")
df
# Out:
#        interaction_date  interaction_number  \
# 0                   NaN                 NaN
# 1      25/12/2018 17:36                 1.0
# 2                   NaN                 NaN
# 3      20/01/2019 08:19                 1.0
# 4                   NaN                 NaN
# ...                 ...                 ...
# 38044               NaN                 NaN
# 38045    5/5/2019 13:40                 4.0
# 38046     6/5/2019 9:19                 3.0
# 38047     8/5/2019 6:49                 2.0
# 38048     8/5/2019 6:51                 1.0
#
#                                                campaign  \
# 0                                                   NaN
# 1                    NL+BE_Rainbow_Monopoly_Classic_dec
# 2                                                   NaN
# 3                    NL+BE_2018_Rainbow_Gaming_VICE_dec
# 4                                                   NaN
# ...                                                 ...
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#        interaction_date  interaction_number  \
# 0                   NaN                 NaN
# 1      25/12/2018 17:36                 1.0
# 3      20/01/2019 08:19                 1.0
# 4                   NaN                 NaN
# 5      30/01/2019 16:09                 1.0
# ...                 ...                 ...
# 38044               NaN                 NaN
# 38045    5/5/2019 13:40                 4.0
# 38046     6/5/2019 9:19                 3.0
# 38047     8/5/2019 6:49                 2.0
# 38048     8/5/2019 6:51                 1.0
#
#                                                campaign  \
# 0                                                   NaN
# 1                    NL+BE_Rainbow_Monopoly_Classic_dec
# 3                    NL+BE_2018_Rainbow_Gaming_VICE_dec
# 4                                                   NaN
# 5                    NL+BE_2018_Rainbow_Gaming_VICE_dec
# ...                                                 ...
# ...

# %%
df=df[(df['campaign']=='NL_2019_Rainbow_PlayDoh_30%promo_display_apr2019')|(df['campaign']=='NL+BE_Rainbow_Gaming_TTP extra inzet_april2019')|(df['campaign']=='NL_Rainbow_Gaming_TTP_april2019')]
df
# Out:
#        interaction_date  interaction_number  \
# 9      21/04/2019 14:57                 1.0
# 15     20/04/2019 14:14                 2.0
# 16     20/04/2019 14:15                 1.0
# 22     18/04/2019 09:50                16.0
# 23     18/04/2019 14:19                15.0
# ...                 ...                 ...
# 37668     9/5/2019 9:30                 2.0
# 38045    5/5/2019 13:40                 4.0
# 38046     6/5/2019 9:19                 3.0
# 38047     8/5/2019 6:49                 2.0
# 38048     8/5/2019 6:51                 1.0
#
#                                                campaign  \
# 9                       NL_Rainbow_Gaming_TTP_april2019
# 15       NL+BE_Rainbow_Gaming_TTP extra inzet_april2019
# 16       NL+BE_Rainbow_Gaming_TTP extra inzet_april2019
# 22     NL_2019_Rainbow_PlayDoh_30%promo_display_apr2019
# 23                      NL_Rainbow_Gaming_TTP_april2019
# ...                                                 ...
# ...

# %%
df.to_csv('campaign_info3.csv',index=False)
